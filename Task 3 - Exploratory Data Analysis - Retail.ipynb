# %% [markdown]
# # GRIP- The Sparks Foundation(July2022)
# # Data Science & Business Analytics
# # Name - Pranjal Jain
# # Task 3 : Exploratory Data Analysis - Retail

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Reading data from remote link

url = "SampleSuperstore.csv"
df = pd.read_csv(url)
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ### Checking for null values

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df1 = df.drop("Postal Code", axis=1)
df1 = df.drop("Country", axis=1)
df1.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ### Visualize the relation between 'Sales' and 'Profit'

# %%
plt.figure(figsize=(10,5))
plt.scatter(x = df1.Sales, y = df.Profit, )
plt.title("Sales vs Profit", fontweight = "bold", fontsize = 20)
plt.xlabel("Sales", fontsize = 15)
plt.ylabel("Profit", fontsize = 15)
plt.show()

# %% [markdown]
# ### Lets Visualize the relationship between 'Discount' and 'Profit'

# %%
plt.figure(figsize=(10,5))
plt.scatter(x = df1.Discount, y = df.Profit, )
plt.title("Discount vs Profit", fontweight = 'bold', fontsize = 20)
plt.xlabel("Discount", fontsize = 15)
plt.ylabel("Profit", fontsize = 15)
plt.show()

# %% [markdown]
# ### Lets check trends of Sales for "Segment"

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = 'Segment', data = df1)
plt.show()

# %%
df1['Segment'].value_counts().plot.pie(figsize = (6,6), autopct = '%.2f')
plt.title("Segment wise sales pie chart", fontweight = 'bold', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Segment wise sales pie chart')

# %% [markdown]
# ### Lets check trends of sales for "Region"

# %%
plt.figure(figsize = (10 , 5))
sns.countplot(x = 'Region', data = df1)
plt.show()

# %%
df1['Region'].value_counts().plot.pie(figsize = (6,6), autopct = '%.2f')
plt.title("Region wise sales pie chart", fontweight = 'bold', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Region wise sales pie chart')

# %% [markdown]
# ### Check trends of sales for "Category"

# %%
plt.figure(figsize = (10, 5))
sns.countplot(x = "Category", data = df1)
plt.show()

# %%
df1['Category'].value_counts().plot.pie(figsize = (6,6), autopct = '%.2f')
plt.title("Category wise sales pie chart", fontweight = 'bold', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Category wise sales pie chart')

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "Sub-Category", data = df1)
plt.xticks(rotation = (90))
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.countplot(x = "State", data = df1)
plt.xticks(rotation = (90))
plt.show()

# %%
df.hist(figsize=(10,10),bins=50)
plt.show()
